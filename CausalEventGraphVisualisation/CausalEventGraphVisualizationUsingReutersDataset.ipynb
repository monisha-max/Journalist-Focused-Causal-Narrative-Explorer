# %%
import spacy
import networkx as nx
import plotly.graph_objects as go
from datetime import datetime
import nltk
import re
from nltk.corpus import reuters

nltk.download('reuters')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nlp = spacy.load('en_core_web_sm')

coreference_mapping = {
    'oil spill': ['spill', 'oil leak', 'incident'],
    'government': ['authorities', 'government', 'Environmental Agency'],
    'local communities': ['residents', 'local community', 'local communities'],
}

def resolve_coreferences(text):
    for key, values in coreference_mapping.items():
        for value in values:
            text = re.sub(r'\b' + re.escape(value) + r'\b', key, text, flags=re.IGNORECASE)
    return text

def extract_events(text):
    doc = nlp(text)
    events = []
    for sent in doc.sents:
        verbs = [token for token in sent if token.pos_ == 'VERB']
        for verb in verbs:
            subject = ''
            objects = []
            for child in verb.children:
                if child.dep_ in ['nsubj', 'nsubjpass']:
                    subject = child.text
                if child.dep_ in ['dobj', 'pobj', 'dative']:
                    objects.append(child.text)
            event = {
                'sentence': sent.text,
                'verb': verb.lemma_,
                'subject': subject,
                'objects': objects
            }
            events.append(event)
    return events

def process_dataset(entries, date_key='date'):
    events = []
    for entry in entries:
        text = entry.get('content')
        if text:
            extracted_events = extract_events(text)
            for event in extracted_events:
                event_date = entry.get(date_key, 'Unknown')
                event['date'] = event_date
                events.append(event)
    return events

def load_reuters_data(max_lines=5000):
    file_ids = reuters.fileids()
    documents = []
    total_lines = 0

    for file_id in file_ids:
        content = reuters.raw(file_id)
        lines = content.splitlines()
        num_lines = len(lines)

        if total_lines + num_lines < max_lines:
            documents.append({'content': content, 'date': 'Unknown'})
            total_lines += num_lines
        else:
            remaining_lines = max_lines - total_lines
            limited_content = '\n'.join(lines[:remaining_lines])
            documents.append({'content': limited_content, 'date': 'Unknown'})
            break
    return documents

reuters_documents = load_reuters_data()
news_events = process_dataset(reuters_documents)

for event in news_events:
    date_str = event['date']
    try:
        if date_str != 'Unknown':
            event['date'] = datetime.strptime(date_str, '%Y-%m-%d')
        else:
            event['date'] = datetime.max
    except ValueError:
        event['date'] = datetime.max

all_events_sorted = sorted(news_events, key=lambda x: x['date'])

max_events = 100
all_events_sorted = all_events_sorted[:max_events]

for event in all_events_sorted:
    event['sentence'] = resolve_coreferences(event['sentence'])
    event['subject'] = resolve_coreferences(event['subject'])
    event['objects'] = [resolve_coreferences(obj) for obj in event['objects']]

G = nx.DiGraph()

for event in all_events_sorted:
    event_id = hash((event['sentence'], event['date']))
    G.add_node(event_id, label=event['sentence'], date=event['date'].strftime('%Y-%m-%d'))

pos = nx.kamada_kawai_layout(G)

edge_x, edge_y = [], []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.extend([x0, x1, None])
    edge_y.extend([y0, y1, None])

node_x, node_y, node_text = [], [], []
for node in G.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)
    node_text.append(f"{G.nodes[node]['label']} ({G.nodes[node]['date']})")

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=1, color='#888'),
    hoverinfo='none',
    mode='lines')

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers+text',
    hoverinfo='text',
    text=node_text,
    textposition="top center",
    marker=dict(
        color='#FFA07A',
        size=20,
        line_width=2))

fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='Causal Graph of Reuters Events',
                    title_x=0.5,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20, l=5, r=5, t=40)))

fig.show()

print("Extracted Events:")
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(all_events_sorted)
# Out:
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="707ebd18-8533-4bb8-b747-a349498ae464" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("707ebd18-8533-4bb8-b747-a349498ae464")) {                    Plotly.newPlot(                        "707ebd18-8533-4bb8-b747-a349498ae464",                        [{"hoverinfo":"none","line":{"color":"#888","width":1},"mode":"lines","x":[],"y":[],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"#FFA07A","line":{"width":2},"size":20},"mode":"markers+text","text":["ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n  Mounting trade friction between the\n  U.S. And Japan has raised fears among many of Asia's exporting\n  nations that the row could inflict far-reaching economic\n  damage, businessmen and officials said.\n       (9999-12-31)","They told Reuter correspondents in Asian capitals a U.S.\n  Move against Japan might boost protectionist sentiment in the\n  U.S. And lead to curbs on American imports of their products.\n       (9999-12-31)","But some exporters said that while the conflict would hurt\n  them in the long-run, in the short-term Tokyo's loss might be\n  their gain.\n       (9999-12-31)","The U.S. Has said it will impose 300 mln dlrs of tariffs on\n  imports of Japanese electronics goods on April 17, in\n  retaliation for Japan's alleged failure to stick to a pact not\n  to sell semiconductors on world markets at below cost.\n       (9999-12-31)","Unofficial Japanese estimates put the impact of the tariffs\n  at 10 billion dlrs and spokesmen for major electronics firms\n  said they would virtually halt exports of products hit by the\n  new taxes.\n       (9999-12-31)","\"We wouldn't be able to do business,\" said a spokesman for\n  leading Japanese electronics firm Matsushita Electric\n  Industrial Co Ltd &lt;MC.T\u003e.\n       (9999-12-31)","\"If the tariffs remain in place for any length of time\n  beyond a few months it will mean the complete erosion of\n  exports (of goods subject to tariffs) to the U.S.,\" said Tom\n  Murtha, a stock analyst at the Tokyo office of broker &lt;James\n  Capel and Co\u003e.\n       (9999-12-31)","\"We are aware of the seriousness of the U.S. Threat against\n  Japan because it serves as a warning to us,\" said a senior\n  Taiwanese trade official who asked not to be named.\n       (9999-12-31)","Taiwan had a trade trade surplus of 15.6 billion dlrs last\n  year, 95 pct of it with the U.S.\n       (9999-12-31)","The surplus helped swell Taiwan's foreign exchange reserves\n  to 53 billion dlrs, among the world's largest.\n       (9999-12-31)","\"We must quickly open our markets, remove trade barriers and\n  cut import tariffs to allow imports of U.S. Products, if we\n  want to defuse problems from possible U.S. Retaliation,\" said\n  Paul Sheen, chairman of textile exporters &lt;Taiwan Safe Group\u003e.\n       (9999-12-31)","A senior official of South Korea's trade promotion\n  association said the trade dispute between the U.S. And Japan\n  might also lead to pressure on South Korea, whose chief exports\n  are similar to those of Japan.\n       (9999-12-31)","Last year South Korea had a trade surplus of 7.1 billion\n  dlrs with the U.S., Up from 4.9 billion dlrs in 1985.\n       (9999-12-31)","In Malaysia, trade officers and businessmen said tough\n  curbs against Japan might allow hard-hit producers of\n  semiconductors in third countries to expand their sales to the\n  U.S.\n       (9999-12-31)","In Hong Kong, where newspapers have alleged Japan has been\n  selling below-cost semiconductors, some electronics\n  manufacturers share that view. (9999-12-31)","But other businessmen said such\n  a short-term commercial advantage would be outweighed by\n  further U.S. Pressure to bl ...
# Extracted Events:
# [   {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'subject': 'EXPORTERS',
#         'verb': 'fear'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'mount'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['fears'],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'subject': 'Japan',
#         'verb': 'raise'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'export'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['damage'],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'subject': 'row',
#         'verb': 'inflict'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'reach'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'subject': 'businessmen',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['correspondents'],
#         'sentence': 'They told Reuter correspondents in Asian capitals a U.S.\n'
#                     '  Move against Japan might boost protectionist sentiment '
#                     'in the\n'
#                     '  U.S. And lead to curbs on American imports of their '
#                     'products.\n'
#                     '      ',
#         'subject': 'They',
#         'verb': 'tell'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['sentiment'],
#         'sentence': 'They told Reuter correspondents in Asian capitals a U.S.\n'
#                     '  Move against Japan might boost protectionist sentiment '
#                     'in the\n'
#                     '  U.S. And lead to curbs on American imports of their '
#                     'products.\n'
#                     '      ',
#         'subject': 'Move',
#         'verb': 'boost'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'They told Reuter correspondents in Asian capitals a U.S.\n'
#                     '  Move against Japan might boost protectionist sentiment '
#                     'in the\n'
#                     '  U.S. And lead to curbs on American imports of their '
#                     'products.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'lead'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'But some exporters said that while the conflict would '
#                     'hurt\n'
#                     "  them in the long-run, in the short-term Tokyo's loss "
#                     'might be\n'
#                     '  their gain.\n'
#                     '      ',
#         'subject': 'exporters',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['them'],
#         'sentence': 'But some exporters said that while the conflict would '
#                     'hurt\n'
#                     "  them in the long-run, in the short-term Tokyo's loss "
#                     'might be\n'
#                     '  their gain.\n'
#                     '      ',
#         'subject': 'conflict',
#         'verb': 'hurt'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The U.S. Has said it will impose 300 mln dlrs of tariffs '
#                     'on\n'
#                     '  imports of Japanese electronics goods on April 17, in\n'
#                     "  retaliation for Japan's alleged failure to stick to a "
#                     'pact not\n'
#                     '  to sell semiconductors on world markets at below cost.\n'
#                     '      ',
#         'subject': 'U.S.',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['dlrs'],
#         'sentence': 'The U.S. Has said it will impose 300 mln dlrs of tariffs '
#                     'on\n'
#                     '  imports of Japanese electronics goods on April 17, in\n'
#                     "  retaliation for Japan's alleged failure to stick to a "
#                     'pact not\n'
#                     '  to sell semiconductors on world markets at below cost.\n'
#                     '      ',
#         'subject': 'it',
#         'verb': 'impose'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The U.S. Has said it will impose 300 mln dlrs of tariffs '
#                     'on\n'
#                     '  imports of Japanese electronics goods on April 17, in\n'
#                     "  retaliation for Japan's alleged failure to stick to a "
#                     'pact not\n'
#                     '  to sell semiconductors on world markets at below cost.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'allege'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The U.S. Has said it will impose 300 mln dlrs of tariffs '
#                     'on\n'
#                     '  imports of Japanese electronics goods on April 17, in\n'
#                     "  retaliation for Japan's alleged failure to stick to a "
#                     'pact not\n'
#                     '  to sell semiconductors on world markets at below cost.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'stick'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['semiconductors'],
#         'sentence': 'The U.S. Has said it will impose 300 mln dlrs of tariffs '
#                     'on\n'
#                     '  imports of Japanese electronics goods on April 17, in\n'
#                     "  retaliation for Japan's alleged failure to stick to a "
#                     'pact not\n'
#                     '  to sell semiconductors on world markets at below cost.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'sell'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['impact'],
#         'sentence': 'Unofficial Japanese estimates put the impact of the '
#                     'tariffs\n'
#                     '  at 10 billion dlrs and spokesmen for major electronics '
#                     'firms\n'
#                     '  said they would virtually halt exports of products hit '
#                     'by the\n'
#                     '  new taxes.\n'
#                     '      ',
#         'subject': 'estimates',
#         'verb': 'put'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'Unofficial Japanese estimates put the impact of the '
#                     'tariffs\n'
#                     '  at 10 billion dlrs and spokesmen for major electronics '
#                     'firms\n'
#                     '  said they would virtually halt exports of products hit '
#                     'by the\n'
#                     '  new taxes.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['exports'],
#         'sentence': 'Unofficial Japanese estimates put the impact of the '
#                     'tariffs\n'
#                     '  at 10 billion dlrs and spokesmen for major electronics '
#                     'firms\n'
#                     '  said they would virtually halt exports of products hit '
#                     'by the\n'
#                     '  new taxes.\n'
#                     '      ',
#         'subject': 'they',
#         'verb': 'halt'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'Unofficial Japanese estimates put the impact of the '
#                     'tariffs\n'
#                     '  at 10 billion dlrs and spokesmen for major electronics '
#                     'firms\n'
#                     '  said they would virtually halt exports of products hit '
#                     'by the\n'
#                     '  new taxes.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'hit'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['business'],
#         'sentence': '"We wouldn\'t be able to do business," said a spokesman '
#                     'for\n'
#                     '  leading Japanese electronics firm Matsushita Electric\n'
#                     '  Industrial Co Ltd &lt;MC.T>.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'do'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We wouldn\'t be able to do business," said a spokesman '
#                     'for\n'
#                     '  leading Japanese electronics firm Matsushita Electric\n'
#                     '  Industrial Co Ltd &lt;MC.T>.\n'
#                     '      ',
#         'subject': 'spokesman',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We wouldn\'t be able to do business," said a spokesman '
#                     'for\n'
#                     '  leading Japanese electronics firm Matsushita Electric\n'
#                     '  Industrial Co Ltd &lt;MC.T>.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'lead'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"If the tariffs remain in place for any length of time\n'
#                     '  beyond a few months it will mean the complete erosion '
#                     'of\n'
#                     '  exports (of goods subject to tariffs) to the U.S.," '
#                     'said Tom\n'
#                     '  Murtha, a stock analyst at the Tokyo office of broker '
#                     '&lt;James\n'
#                     '  Capel and Co>.\n'
#                     '      ',
#         'subject': 'tariffs',
#         'verb': 'remain'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['erosion'],
#         'sentence': '"If the tariffs remain in place for any length of time\n'
#                     '  beyond a few months it will mean the complete erosion '
#                     'of\n'
#                     '  exports (of goods subject to tariffs) to the U.S.," '
#                     'said Tom\n'
#                     '  Murtha, a stock analyst at the Tokyo office of broker '
#                     '&lt;James\n'
#                     '  Capel and Co>.\n'
#                     '      ',
#         'subject': 'it',
#         'verb': 'mean'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"If the tariffs remain in place for any length of time\n'
#                     '  beyond a few months it will mean the complete erosion '
#                     'of\n'
#                     '  exports (of goods subject to tariffs) to the U.S.," '
#                     'said Tom\n'
#                     '  Murtha, a stock analyst at the Tokyo office of broker '
#                     '&lt;James\n'
#                     '  Capel and Co>.\n'
#                     '      ',
#         'subject': 'Murtha',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We are aware of the seriousness of the U.S. Threat '
#                     'against\n'
#                     '  Japan because it serves as a warning to us," said a '
#                     'senior\n'
#                     '  Taiwanese trade official who asked not to be named.\n'
#                     '      ',
#         'subject': 'it',
#         'verb': 'serve'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We are aware of the seriousness of the U.S. Threat '
#                     'against\n'
#                     '  Japan because it serves as a warning to us," said a '
#                     'senior\n'
#                     '  Taiwanese trade official who asked not to be named.\n'
#                     '      ',
#         'subject': 'official',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We are aware of the seriousness of the U.S. Threat '
#                     'against\n'
#                     '  Japan because it serves as a warning to us," said a '
#                     'senior\n'
#                     '  Taiwanese trade official who asked not to be named.\n'
#                     '      ',
#         'subject': 'who',
#         'verb': 'ask'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We are aware of the seriousness of the U.S. Threat '
#                     'against\n'
#                     '  Japan because it serves as a warning to us," said a '
#                     'senior\n'
#                     '  Taiwanese trade official who asked not to be named.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'name'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['surplus'],
#         'sentence': 'Taiwan had a trade trade surplus of 15.6 billion dlrs '
#                     'last\n'
#                     '  year, 95 pct of it with the U.S.\n'
#                     '      ',
#         'subject': 'Taiwan',
#         'verb': 'have'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "The surplus helped swell Taiwan's foreign exchange "
#                     'reserves\n'
#                     "  to 53 billion dlrs, among the world's largest.\n"
#                     '      ',
#         'subject': 'surplus',
#         'verb': 'help'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['reserves'],
#         'sentence': "The surplus helped swell Taiwan's foreign exchange "
#                     'reserves\n'
#                     "  to 53 billion dlrs, among the world's largest.\n"
#                     '      ',
#         'subject': '',
#         'verb': 'swell'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['markets'],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'subject': 'We',
#         'verb': 'open'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['barriers'],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'remove'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['tariffs'],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'cut'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['imports'],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'allow'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'subject': 'we',
#         'verb': 'want'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['problems'],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'defuse'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'subject': 'Sheen',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "A senior official of South Korea's trade promotion\n"
#                     '  association said the trade dispute between the U.S. And '
#                     'Japan\n'
#                     '  might also lead to pressure on South Korea, whose chief '
#                     'exports\n'
#                     '  are similar to those of Japan.\n'
#                     '      ',
#         'subject': 'official',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "A senior official of South Korea's trade promotion\n"
#                     '  association said the trade dispute between the U.S. And '
#                     'Japan\n'
#                     '  might also lead to pressure on South Korea, whose chief '
#                     'exports\n'
#                     '  are similar to those of Japan.\n'
#                     '      ',
#         'subject': 'dispute',
#         'verb': 'lead'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['surplus'],
#         'sentence': 'Last year South Korea had a trade surplus of 7.1 billion\n'
#                     '  dlrs with the U.S., Up from 4.9 billion dlrs in 1985.\n'
#                     '      ',
#         'subject': 'Korea',
#         'verb': 'have'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'In Malaysia, trade officers and businessmen said tough\n'
#                     '  curbs against Japan might allow hard-hit producers of\n'
#                     '  semiconductors in third countries to expand their sales '
#                     'to the\n'
#                     '  U.S.\n'
#                     '      ',
#         'subject': 'officers',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'In Malaysia, trade officers and businessmen said tough\n'
#                     '  curbs against Japan might allow hard-hit producers of\n'
#                     '  semiconductors in third countries to expand their sales '
#                     'to the\n'
#                     '  U.S.\n'
#                     '      ',
#         'subject': 'curbs',
#         'verb': 'allow'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'In Malaysia, trade officers and businessmen said tough\n'
#                     '  curbs against Japan might allow hard-hit producers of\n'
#                     '  semiconductors in third countries to expand their sales '
#                     'to the\n'
#                     '  U.S.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'hit'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['sales'],
#         'sentence': 'In Malaysia, trade officers and businessmen said tough\n'
#                     '  curbs against Japan might allow hard-hit producers of\n'
#                     '  semiconductors in third countries to expand their sales '
#                     'to the\n'
#                     '  U.S.\n'
#                     '      ',
#         'subject': 'producers',
#         'verb': 'expand'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'In Hong Kong, where newspapers have alleged Japan has '
#                     'been\n'
#                     '  selling below-cost semiconductors, some electronics\n'
#                     '  manufacturers share that view.',
#         'subject': 'newspapers',
#         'verb': 'allege'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['semiconductors'],
#         'sentence': 'In Hong Kong, where newspapers have alleged Japan has '
#                     'been\n'
#                     '  selling below-cost semiconductors, some electronics\n'
#                     '  manufacturers share that view.',
#         'subject': 'Japan',
#         'verb': 'sell'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['view'],
#         'sentence': 'In Hong Kong, where newspapers have alleged Japan has '
#                     'been\n'
#                     '  selling below-cost semiconductors, some electronics\n'
#                     '  manufacturers share that view.',
#         'subject': 'manufacturers',
#         'verb': 'share'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'But other businessmen said such\n'
#                     '  a short-term commercial advantage would be outweighed '
#                     'by\n'
#                     '  further U.S. Pressure to block imports.\n'
#                     '      ',
#         'subject': 'businessmen',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'But other businessmen said such\n'
#                     '  a short-term commercial advantage would be outweighed '
#                     'by\n'
#                     '  further U.S. Pressure to block imports.\n'
#                     '      ',
#         'subject': 'advantage',
#         'verb': 'outweigh'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['imports'],
#         'sentence': 'But other businessmen said such\n'
#                     '  a short-term commercial advantage would be outweighed '
#                     'by\n'
#                     '  further U.S. Pressure to block imports.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'block'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"That is a very short-term view," said Lawrence Mills,\n'
#                     '  director-general of the Federation of Hong Kong '
#                     'Industry.\n'
#                     '      ',
#         'subject': 'Mills',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['imports'],
#         'sentence': '"If the whole purpose is to prevent imports, one day it '
#                     'will\n'
#                     '  be extended to other sources.',
#         'subject': '',
#         'verb': 'prevent'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"If the whole purpose is to prevent imports, one day it '
#                     'will\n'
#                     '  be extended to other sources.',
#         'subject': 'it',
#         'verb': 'extend'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['trade'],
#         'sentence': 'Much more serious for Hong Kong\n'
#                     '  is the disadvantage of action restraining trade," he '
#                     'said.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'restrain'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'Much more serious for Hong Kong\n'
#                     '  is the disadvantage of action restraining trade," he '
#                     'said.\n'
#                     '      ',
#         'subject': 'he',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "Last year was Hong Kong's biggest export market,\n"
#                     '  accounting for over 30 pct of domestically produced '
#                     'exports.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'account'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "Last year was Hong Kong's biggest export market,\n"
#                     '  accounting for over 30 pct of domestically produced '
#                     'exports.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'produce'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['outcome'],
#         'sentence': 'The Australian government is awaiting the outcome of '
#                     'trade\n'
#                     '  talks between the U.S. And Japan with interest and '
#                     'concern,\n'
#                     '  Industry Minister John Button said in Canberra last '
#                     'Friday.\n'
#                     '      ',
#         'subject': 'government',
#         'verb': 'await'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The Australian government is awaiting the outcome of '
#                     'trade\n'
#                     '  talks between the U.S. And Japan with interest and '
#                     'concern,\n'
#                     '  Industry Minister John Button said in Canberra last '
#                     'Friday.\n'
#                     '      ',
#         'subject': 'Button',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"This kind of deterioration in trade relations between '
#                     'two\n'
#                     '  countries which are major trading partners of ours is a '
#                     'very\n'
#                     '  serious matter," Button said.\n'
#                     '      ',
#         'subject': 'Button',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['concerns'],
#         'sentence': "He said Australia's concerns centred on coal and beef,\n"
#                     "  Australia's two largest exports to Japan and also "
#                     'significant\n'
#                     '  U.S. Exports to that country.\n'
#                     '      ',
#         'subject': 'He',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "He said Australia's concerns centred on coal and beef,\n"
#                     "  Australia's two largest exports to Japan and also "
#                     'significant\n'
#                     '  U.S. Exports to that country.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'centre'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['off'],
#         'sentence': 'Meanwhile U.S.-Japanese diplomatic manoeuvres to solve '
#                     'the\n'
#                     '  trade stand-off continue.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'solve'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "Japan's ruling Liberal Democratic Party yesterday "
#                     'outlined\n'
#                     '  a package of economic measures to boost the Japanese '
#                     'economy.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'rule'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['package'],
#         'sentence': "Japan's ruling Liberal Democratic Party yesterday "
#                     'outlined\n'
#                     '  a package of economic measures to boost the Japanese '
#                     'economy.\n'
#                     '      ',
#         'subject': 'Party',
#         'verb': 'outline'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['economy'],
#         'sentence': "Japan's ruling Liberal Democratic Party yesterday "
#                     'outlined\n'
#                     '  a package of economic measures to boost the Japanese '
#                     'economy.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'boost'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The measures proposed include a large supplementary '
#                     'budget\n'
#                     '  and record public works spending in the first half of '
#                     'the\n'
#                     '  financial year.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'propose'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['budget'],
#         'sentence': 'The measures proposed include a large supplementary '
#                     'budget\n'
#                     '  and record public works spending in the first half of '
#                     'the\n'
#                     '  financial year.\n'
#                     '      ',
#         'subject': 'measures',
#         'verb': 'include'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The measures proposed include a large supplementary '
#                     'budget\n'
#                     '  and record public works spending in the first half of '
#                     'the\n'
#                     '  financial year.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'record'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'They also call for stepped-up spending as an emergency\n'
#                     '  measure to stimulate the economy despite Prime '
#                     'Minister\n'
#                     "  Yasuhiro Nakasone's avowed fiscal reform program.\n"
#                     '      ',
#         'subject': 'They',
#         'verb': 'call'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'They also call for stepped-up spending as an emergency\n'
#                     '  measure to stimulate the economy despite Prime '
#                     'Minister\n'
#                     "  Yasuhiro Nakasone's avowed fiscal reform program.\n"
#                     '      ',
#         'subject': '',
#         'verb': 'step'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['economy'],
#         'sentence': 'They also call for stepped-up spending as an emergency\n'
#                     '  measure to stimulate the economy despite Prime '
#                     'Minister\n'
#                     "  Yasuhiro Nakasone's avowed fiscal reform program.\n"
#                     '      ',
#         'subject': '',
#         'verb': 'stimulate'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'They also call for stepped-up spending as an emergency\n'
#                     '  measure to stimulate the economy despite Prime '
#                     'Minister\n'
#                     "  Yasuhiro Nakasone's avowed fiscal reform program.\n"
#                     '      ',
#         'subject': '',
#         'verb': 'avow'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'Deputy U.S. Trade Representative Michael Smith and '
#                     'Makoto\n'
#                     "  Kuroda, Japan's deputy minister of International Trade "
#                     'and\n'
#                     '  Industry (MITI), are due to meet in Washington this '
#                     'week in an\n'
#                     '  effort to end the dispute.\n'
#                     '  \n'
#                     '\n',
#         'subject': '',
#         'verb': 'meet'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['dispute'],
#         'sentence': 'Deputy U.S. Trade Representative Michael Smith and '
#                     'Makoto\n'
#                     "  Kuroda, Japan's deputy minister of International Trade "
#                     'and\n'
#                     '  Industry (MITI), are due to meet in Washington this '
#                     'week in an\n'
#                     '  effort to end the dispute.\n'
#                     '  \n'
#                     '\n',
#         'subject': '',
#         'verb': 'end'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['EAT'],
#         'sentence': 'CHINA DAILY SAYS VERMIN EAT 7-12 PCT GRAIN STOCKS\n'
#                     '  A survey of 19 provinces and seven cities\n'
#                     '  showed vermin consume between seven and 12 pct of '
#                     "China's grain\n"
#                     '  stocks, the China Daily said.\n'
#                     '      ',
#         'subject': 'DAILY',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['consume'],
#         'sentence': 'CHINA DAILY SAYS VERMIN EAT 7-12 PCT GRAIN STOCKS\n'
#                     '  A survey of 19 provinces and seven cities\n'
#                     '  showed vermin consume between seven and 12 pct of '
#                     "China's grain\n"
#                     '  stocks, the China Daily said.\n'
#                     '      ',
#         'subject': 'survey',
#         'verb': 'show'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'CHINA DAILY SAYS VERMIN EAT 7-12 PCT GRAIN STOCKS\n'
#                     '  A survey of 19 provinces and seven cities\n'
#                     '  showed vermin consume between seven and 12 pct of '
#                     "China's grain\n"
#                     '  stocks, the China Daily said.\n'
#                     '      ',
#         'subject': 'Daily',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'It also said that each year 1.575 mln tonnes, or 25 pct, '
#                     'of\n'
#                     "  China's fruit output are left to rot, and 2.1 mln "
#                     'tonnes, or up\n'
#                     '  to 30 pct, of its vegetables.',
#         'subject': 'It',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'It also said that each year 1.575 mln tonnes, or 25 pct, '
#                     'of\n'
#                     "  China's fruit output are left to rot, and 2.1 mln "
#                     'tonnes, or up\n'
#                     '  to 30 pct, of its vegetables.',
#         'subject': 'tonnes',
#         'verb': 'leave'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'It also said that each year 1.575 mln tonnes, or 25 pct, '
#                     'of\n'
#                     "  China's fruit output are left to rot, and 2.1 mln "
#                     'tonnes, or up\n'
#                     '  to 30 pct, of its vegetables.',
#         'subject': '',
#         'verb': 'rot'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['waste'],
#         'sentence': 'The paper blamed the waste on\n'
#                     '  inadequate storage and bad preservation methods.\n'
#                     '      ',
#         'subject': 'paper',
#         'verb': 'blame'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'It said the government had launched a national programme '
#                     'to\n'
#                     '  reduce waste, calling for improved technology in '
#                     'storage and\n'
#                     '  preservation, and greater production of additives.',
#         'subject': 'It',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['programme'],
#         'sentence': 'It said the government had launched a national programme '
#                     'to\n'
#                     '  reduce waste, calling for improved technology in '
#                     'storage and\n'
#                     '  preservation, and greater production of additives.',
#         'subject': 'government',
#         'verb': 'launch'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['waste'],
#         'sentence': 'It said the government had launched a national programme '
#                     'to\n'
#                     '  reduce waste, calling for improved technology in '
#                     'storage and\n'
#                     '  preservation, and greater production of additives.',
#         'subject': '',
#         'verb': 'reduce'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'It said the government had launched a national programme '
#                     'to\n'
#                     '  reduce waste, calling for improved technology in '
#                     'storage and\n'
#                     '  preservation, and greater production of additives.',
#         'subject': '',
#         'verb': 'call'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['details'],
#         'sentence': 'The paper\n  gave no further details.\n  \n\n',
#         'subject': 'paper',
#         'verb': 'give'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'JAPAN TO REVISE LONG-TERM ENERGY DEMAND DOWNWARDS\n'
#                     '  The Ministry of International Trade and\n'
#                     '  Industry (MITI) will revise its long-term energy '
#                     'supply/demand\n'
#                     '  outlook by August to meet a forecast downtrend in '
#                     'Japanese\n'
#                     '  energy demand, ministry officials said.\n'
#                     '      ',
#         'subject': 'JAPAN',
#         'verb': 'revise'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['outlook'],
#         'sentence': 'JAPAN TO REVISE LONG-TERM ENERGY DEMAND DOWNWARDS\n'
#                     '  The Ministry of International Trade and\n'
#                     '  Industry (MITI) will revise its long-term energy '
#                     'supply/demand\n'
#                     '  outlook by August to meet a forecast downtrend in '
#                     'Japanese\n'
#                     '  energy demand, ministry officials said.\n'
#                     '      ',
#         'subject': 'REVISE',
#         'verb': 'revise'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['downtrend'],
#         'sentence': 'JAPAN TO REVISE LONG-TERM ENERGY DEMAND DOWNWARDS\n'
#                     '  The Ministry of International Trade and\n'
#                     '  Industry (MITI) will revise its long-term energy '
#                     'supply/demand\n'
#                     '  outlook by August to meet a forecast downtrend in '
#                     'Japanese\n'
#                     '  energy demand, ministry officials said.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'meet'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'JAPAN TO REVISE LONG-TERM ENERGY DEMAND DOWNWARDS\n'
#                     '  The Ministry of International Trade and\n'
#                     '  Industry (MITI) will revise its long-term energy '
#                     'supply/demand\n'
#                     '  outlook by August to meet a forecast downtrend in '
#                     'Japanese\n'
#                     '  energy demand, ministry officials said.\n'
#                     '      ',
#         'subject': 'officials',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'MITI is expected to lower the projection for primary '
#                     'energy\n'
#                     '  supplies in the year 2000 to 550 mln kilolitres (kl) '
#                     'from 600\n'
#                     '  mln, they said.\n'
#                     '      ',
#         'subject': 'MITI',
#         'verb': 'expect'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['projection'],
#         'sentence': 'MITI is expected to lower the projection for primary '
#                     'energy\n'
#                     '  supplies in the year 2000 to 550 mln kilolitres (kl) '
#                     'from 600\n'
#                     '  mln, they said.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'lower'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'MITI is expected to lower the projection for primary '
#                     'energy\n'
#                     '  supplies in the year 2000 to 550 mln kilolitres (kl) '
#                     'from 600\n'
#                     '  mln, they said.\n'
#                     '      ',
#         'subject': 'they',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['emergence'],
#         'sentence': 'The decision follows the emergence of structural changes '
#                     'in\n'
#                     '  Japanese industry following the rise in the value of '
#                     'the yen\n'
#                     '  and a decline in domestic electric power demand.\n'
#                     '      ',
#         'subject': 'decision',
#         'verb': 'follow'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['rise'],
#         'sentence': 'The decision follows the emergence of structural changes '
#                     'in\n'
#                     '  Japanese industry following the rise in the value of '
#                     'the yen\n'
#                     '  and a decline in domestic electric power demand.\n'
#                     '      ',
#         'subject': '',
#         'verb': 'follow'}]

# %%
import spacy
import networkx as nx
import plotly.graph_objects as go
from datetime import datetime
import nltk
import re
from nltk.corpus import reuters
from textblob import TextBlob
nltk.download('reuters')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nlp = spacy.load('en_core_web_sm')

coreference_mapping = {
    'oil spill': ['spill', 'oil leak', 'incident'],
    'government': ['authorities', 'government', 'Environmental Agency'],
    'local communities': ['residents', 'local community', 'local communities'],
}

def resolve_coreferences(text):
    for key, values in coreference_mapping.items():
        for value in values:
            text = re.sub(r'\b' + re.escape(value) + r'\b', key, text, flags=re.IGNORECASE)
    return text

def extract_events(text):
    doc = nlp(text)
    events = []
    for sent in doc.sents:
        verbs = [token for token in sent if token.pos_ == 'VERB']
        for verb in verbs:
            subject = ''
            objects = []
            for child in verb.children:
                if child.dep_ in ['nsubj', 'nsubjpass']:
                    subject = child.text
                if child.dep_ in ['dobj', 'pobj', 'dative']:
                    objects.append(child.text)
            event = {
                'sentence': sent.text,
                'verb': verb.lemma_,
                'subject': subject,
                'objects': objects
            }
            events.append(event)
    return events

def process_dataset(entries, date_key='date'):
    events = []
    for entry in entries:
        text = entry.get('content')
        if text:
            extracted_events = extract_events(text)
            for event in extracted_events:
                event_date = entry.get(date_key, 'Unknown')
                event['date'] = event_date
                events.append(event)
    return events

def load_reuters_data(max_lines=5000):
    file_ids = reuters.fileids()
    documents = []
    total_lines = 0

    for file_id in file_ids:
        content = reuters.raw(file_id)
        lines = content.splitlines()
        num_lines = len(lines)

        if total_lines + num_lines < max_lines:
            documents.append({'content': content, 'date': 'Unknown'})
            total_lines += num_lines
        else:
            remaining_lines = max_lines - total_lines
            limited_content = '\n'.join(lines[:remaining_lines])
            documents.append({'content': limited_content, 'date': 'Unknown'})
            break
    return documents

reuters_documents = load_reuters_data()

news_events = process_dataset(reuters_documents)

for event in news_events:
    date_str = event['date']
    try:
        if date_str != 'Unknown':
            event['date'] = datetime.strptime(date_str, '%Y-%m-%d')
        else:
            event['date'] = datetime.max
    except ValueError:
        event['date'] = datetime.max

all_events_sorted = sorted(news_events, key=lambda x: x['date'])

max_events = 100
all_events_sorted = all_events_sorted[:max_events]

for event in all_events_sorted:
    event['sentence'] = resolve_coreferences(event['sentence'])
    event['subject'] = resolve_coreferences(event['subject'])
    event['objects'] = [resolve_coreferences(obj) for obj in event['objects']]

def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity < 0:
        return 'negative'
    else:
        return 'neutral'

for event in all_events_sorted:
    event['sentiment'] = get_sentiment(event['sentence'])

causal_keywords = ['cause', 'lead to', 'result in', 'due to', 'because']

def find_causal_relations(events):
    causal_relations = []
    for i, event_i in enumerate(events):
        for j, event_j in enumerate(events):
            if i != j:
                for keyword in causal_keywords:
                    if keyword in event_j['sentence']:
                        causal_relations.append((event_i, event_j))
    return causal_relations

causal_relations = find_causal_relations(all_events_sorted)

G = nx.DiGraph()

for event in all_events_sorted:
    event_id = hash((event['sentence'], event['date']))
    G.add_node(event_id, label=event['sentence'], date=event['date'].strftime('%Y-%m-%d'), sentiment=event['sentiment'])

for source, target in causal_relations:
    source_id = hash((source['sentence'], source['date']))
    target_id = hash((target['sentence'], target['date']))
    G.add_edge(source_id, target_id, label='causes')

pos = nx.kamada_kawai_layout(G)

edge_x, edge_y, edge_labels = [], [], []
for edge in G.edges(data=True):
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.extend([x0, x1, None])
    edge_y.extend([y0, y1, None])
    edge_labels.append(edge[2]['label'])

node_x, node_y, node_text, node_colors = [], [], [], []
for node in G.nodes(data=True):
    x, y = pos[node[0]]
    node_x.append(x)
    node_y.append(y)
    node_text.append(f"{node[1]['label']} (Sentiment: {node[1]['sentiment']})")
    if node[1]['sentiment'] == 'positive':
        node_colors.append('#76c7c0')
    elif node[1]['sentiment'] == 'negative':
        node_colors.append('#ff6f61')
    else:
        node_colors.append('#ffa500')

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=2, color='#000000'),
    hoverinfo='text',
    mode='lines')

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers+text',
    hoverinfo='text',
    text=node_text,
    textposition="top center",
    marker=dict(
        color=node_colors,
        size=20,
        line_width=2))

fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='Enhanced Causal Graph of Reuters Events',
                    title_x=0.5,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20, l=5, r=5, t=40)))

fig.show()

print("Extracted Events:")
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(all_events_sorted)
# Out:
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4458a01b-0276-4dce-9724-7a242a397cc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4458a01b-0276-4dce-9724-7a242a397cc0")) {                    Plotly.newPlot(                        "4458a01b-0276-4dce-9724-7a242a397cc0",                        [{"hoverinfo":"text","line":{"color":"#000000","width":2},"mode":"lines","x":[0.9999628481383472,0.0839187543294385,null,0.9999628481383472,0.08563618053918397,null,0.9999628481383472,0.036942328447935345,null,0.9999628481383472,0.000779007380808747,null,0.0839187543294385,0.0839187543294385,null,0.0839187543294385,0.08563618053918397,null,0.0839187543294385,0.036942328447935345,null,0.0839187543294385,0.000779007380808747,null,1.0,0.0839187543294385,null,1.0,0.08563618053918397,null,1.0,0.036942328447935345,null,1.0,0.000779007380808747,null,0.9999986835732383,0.0839187543294385,null,0.9999986835732383,0.08563618053918397,null,0.9999986835732383,0.036942328447935345,null,0.9999986835732383,0.000779007380808747,null,0.9999617721156349,0.0839187543294385,null,0.9999617721156349,0.08563618053918397,null,0.9999617721156349,0.036942328447935345,null,0.9999617721156349,0.000779007380808747,null,0.9998816802423723,0.0839187543294385,null,0.9998816802423723,0.08563618053918397,null,0.9998816802423723,0.036942328447935345,null,0.9998816802423723,0.000779007380808747,null,0.9998070395873428,0.0839187543294385,null,0.9998070395873428,0.08563618053918397,null,0.9998070395873428,0.036942328447935345,null,0.9998070395873428,0.000779007380808747,null,0.08563618053918397,0.0839187543294385,null,0.08563618053918397,0.08563618053918397,null,0.08563618053918397,0.036942328447935345,null,0.08563618053918397,0.000779007380808747,null,0.9998365979057907,0.0839187543294385,null,0.9998365979057907,0.08563618053918397,null,0.9998365979057907,0.036942328447935345,null,0.9998365979057907,0.000779007380808747,null,-0.8946399464823849,0.0839187543294385,null,-0.8946399464823849,0.08563618053918397,null,-0.8946399464823849,0.036942328447935345,null,-0.8946399464823849,0.000779007380808747,null,-0.8944947280107898,0.0839187543294385,null,-0.8944947280107898,0.08563618053918397,null,-0.8944947280107898,0.036942328447935345,null,-0.8944947280107898,0.000779007380808747,null,0.036942328447935345,0.0839187543294385,null,0.036942328447935345,0.08563618053918397,null,0.036942328447935345,0.036942328447935345,null,0.036942328447935345,0.000779007380808747,null,-0.8945214793202831,0.0839187543294385,null,-0.8945214793202831,0.08563618053918397,null,-0.8945214793202831,0.036942328447935345,null,-0.8945214793202831,0.000779007380808747,null,-0.8945228548793924,0.0839187543294385,null,-0.8945228548793924,0.08563618053918397,null,-0.8945228548793924,0.036942328447935345,null,-0.8945228548793924,0.000779007380808747,null,-0.894500941003227,0.0839187543294385,null,-0.894500941003227,0.08563618053918397,null,-0.894500941003227,0.036942328447935345,null,-0.894500941003227,0.000779007380808747,null,-0.8944704696668395,0.0839187543294385,null,-0.8944704696668395,0.08563618053918397,null,-0.8944704696668395,0.036942328447935345,null,-0.8944704696668395,0.000779007380808747,null,-0.894444442422031,0.0839187543294385,null,-0.894444442422031,0.08563618053918397,null,-0.894444442422031,0.036942328447935345,null,-0.894444442422031,0.000779007380808747,null,-0.8944362005303864,0.0839187543294385,null,-0.8944362005303864,0.08563618053918397,null,-0.8944362005303864,0.036942328447935345,null,-0.8944362005303864,0.000779007380808747,null,-0.8944542688129102,0.0839187543294385,null,-0.8944542688129102,0.08563618053918397,null,-0.8944542688129102,0.036942328447935345,null,-0.8944542688129102,0.000779007380808747,null,-0.8944983206638 ...
# Extracted Events:
# [   {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'EXPORTERS',
#         'verb': 'fear'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'mount'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['fears'],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'Japan',
#         'verb': 'raise'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'export'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['damage'],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'row',
#         'verb': 'inflict'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'reach'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT\n'
#                     '  Mounting trade friction between the\n'
#                     "  U.S. And Japan has raised fears among many of Asia's "
#                     'exporting\n'
#                     '  nations that the row could inflict far-reaching '
#                     'economic\n'
#                     '  damage, businessmen and officials said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'businessmen',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['correspondents'],
#         'sentence': 'They told Reuter correspondents in Asian capitals a U.S.\n'
#                     '  Move against Japan might boost protectionist sentiment '
#                     'in the\n'
#                     '  U.S. And lead to curbs on American imports of their '
#                     'products.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'They',
#         'verb': 'tell'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['sentiment'],
#         'sentence': 'They told Reuter correspondents in Asian capitals a U.S.\n'
#                     '  Move against Japan might boost protectionist sentiment '
#                     'in the\n'
#                     '  U.S. And lead to curbs on American imports of their '
#                     'products.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'Move',
#         'verb': 'boost'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'They told Reuter correspondents in Asian capitals a U.S.\n'
#                     '  Move against Japan might boost protectionist sentiment '
#                     'in the\n'
#                     '  U.S. And lead to curbs on American imports of their '
#                     'products.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': '',
#         'verb': 'lead'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'But some exporters said that while the conflict would '
#                     'hurt\n'
#                     "  them in the long-run, in the short-term Tokyo's loss "
#                     'might be\n'
#                     '  their gain.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'exporters',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['them'],
#         'sentence': 'But some exporters said that while the conflict would '
#                     'hurt\n'
#                     "  them in the long-run, in the short-term Tokyo's loss "
#                     'might be\n'
#                     '  their gain.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'conflict',
#         'verb': 'hurt'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The U.S. Has said it will impose 300 mln dlrs of tariffs '
#                     'on\n'
#                     '  imports of Japanese electronics goods on April 17, in\n'
#                     "  retaliation for Japan's alleged failure to stick to a "
#                     'pact not\n'
#                     '  to sell semiconductors on world markets at below cost.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'U.S.',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['dlrs'],
#         'sentence': 'The U.S. Has said it will impose 300 mln dlrs of tariffs '
#                     'on\n'
#                     '  imports of Japanese electronics goods on April 17, in\n'
#                     "  retaliation for Japan's alleged failure to stick to a "
#                     'pact not\n'
#                     '  to sell semiconductors on world markets at below cost.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'it',
#         'verb': 'impose'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The U.S. Has said it will impose 300 mln dlrs of tariffs '
#                     'on\n'
#                     '  imports of Japanese electronics goods on April 17, in\n'
#                     "  retaliation for Japan's alleged failure to stick to a "
#                     'pact not\n'
#                     '  to sell semiconductors on world markets at below cost.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': '',
#         'verb': 'allege'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The U.S. Has said it will impose 300 mln dlrs of tariffs '
#                     'on\n'
#                     '  imports of Japanese electronics goods on April 17, in\n'
#                     "  retaliation for Japan's alleged failure to stick to a "
#                     'pact not\n'
#                     '  to sell semiconductors on world markets at below cost.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': '',
#         'verb': 'stick'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['semiconductors'],
#         'sentence': 'The U.S. Has said it will impose 300 mln dlrs of tariffs '
#                     'on\n'
#                     '  imports of Japanese electronics goods on April 17, in\n'
#                     "  retaliation for Japan's alleged failure to stick to a "
#                     'pact not\n'
#                     '  to sell semiconductors on world markets at below cost.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': '',
#         'verb': 'sell'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['impact'],
#         'sentence': 'Unofficial Japanese estimates put the impact of the '
#                     'tariffs\n'
#                     '  at 10 billion dlrs and spokesmen for major electronics '
#                     'firms\n'
#                     '  said they would virtually halt exports of products hit '
#                     'by the\n'
#                     '  new taxes.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'estimates',
#         'verb': 'put'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'Unofficial Japanese estimates put the impact of the '
#                     'tariffs\n'
#                     '  at 10 billion dlrs and spokesmen for major electronics '
#                     'firms\n'
#                     '  said they would virtually halt exports of products hit '
#                     'by the\n'
#                     '  new taxes.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['exports'],
#         'sentence': 'Unofficial Japanese estimates put the impact of the '
#                     'tariffs\n'
#                     '  at 10 billion dlrs and spokesmen for major electronics '
#                     'firms\n'
#                     '  said they would virtually halt exports of products hit '
#                     'by the\n'
#                     '  new taxes.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'they',
#         'verb': 'halt'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'Unofficial Japanese estimates put the impact of the '
#                     'tariffs\n'
#                     '  at 10 billion dlrs and spokesmen for major electronics '
#                     'firms\n'
#                     '  said they would virtually halt exports of products hit '
#                     'by the\n'
#                     '  new taxes.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'hit'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['business'],
#         'sentence': '"We wouldn\'t be able to do business," said a spokesman '
#                     'for\n'
#                     '  leading Japanese electronics firm Matsushita Electric\n'
#                     '  Industrial Co Ltd &lt;MC.T>.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'do'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We wouldn\'t be able to do business," said a spokesman '
#                     'for\n'
#                     '  leading Japanese electronics firm Matsushita Electric\n'
#                     '  Industrial Co Ltd &lt;MC.T>.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'spokesman',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We wouldn\'t be able to do business," said a spokesman '
#                     'for\n'
#                     '  leading Japanese electronics firm Matsushita Electric\n'
#                     '  Industrial Co Ltd &lt;MC.T>.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'lead'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"If the tariffs remain in place for any length of time\n'
#                     '  beyond a few months it will mean the complete erosion '
#                     'of\n'
#                     '  exports (of goods subject to tariffs) to the U.S.," '
#                     'said Tom\n'
#                     '  Murtha, a stock analyst at the Tokyo office of broker '
#                     '&lt;James\n'
#                     '  Capel and Co>.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'tariffs',
#         'verb': 'remain'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['erosion'],
#         'sentence': '"If the tariffs remain in place for any length of time\n'
#                     '  beyond a few months it will mean the complete erosion '
#                     'of\n'
#                     '  exports (of goods subject to tariffs) to the U.S.," '
#                     'said Tom\n'
#                     '  Murtha, a stock analyst at the Tokyo office of broker '
#                     '&lt;James\n'
#                     '  Capel and Co>.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'it',
#         'verb': 'mean'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"If the tariffs remain in place for any length of time\n'
#                     '  beyond a few months it will mean the complete erosion '
#                     'of\n'
#                     '  exports (of goods subject to tariffs) to the U.S.," '
#                     'said Tom\n'
#                     '  Murtha, a stock analyst at the Tokyo office of broker '
#                     '&lt;James\n'
#                     '  Capel and Co>.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'Murtha',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We are aware of the seriousness of the U.S. Threat '
#                     'against\n'
#                     '  Japan because it serves as a warning to us," said a '
#                     'senior\n'
#                     '  Taiwanese trade official who asked not to be named.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'it',
#         'verb': 'serve'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We are aware of the seriousness of the U.S. Threat '
#                     'against\n'
#                     '  Japan because it serves as a warning to us," said a '
#                     'senior\n'
#                     '  Taiwanese trade official who asked not to be named.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'official',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We are aware of the seriousness of the U.S. Threat '
#                     'against\n'
#                     '  Japan because it serves as a warning to us," said a '
#                     'senior\n'
#                     '  Taiwanese trade official who asked not to be named.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'who',
#         'verb': 'ask'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We are aware of the seriousness of the U.S. Threat '
#                     'against\n'
#                     '  Japan because it serves as a warning to us," said a '
#                     'senior\n'
#                     '  Taiwanese trade official who asked not to be named.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'name'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['surplus'],
#         'sentence': 'Taiwan had a trade trade surplus of 15.6 billion dlrs '
#                     'last\n'
#                     '  year, 95 pct of it with the U.S.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'Taiwan',
#         'verb': 'have'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "The surplus helped swell Taiwan's foreign exchange "
#                     'reserves\n'
#                     "  to 53 billion dlrs, among the world's largest.\n"
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'surplus',
#         'verb': 'help'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['reserves'],
#         'sentence': "The surplus helped swell Taiwan's foreign exchange "
#                     'reserves\n'
#                     "  to 53 billion dlrs, among the world's largest.\n"
#                     '      ',
#         'sentiment': 'negative',
#         'subject': '',
#         'verb': 'swell'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['markets'],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'We',
#         'verb': 'open'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['barriers'],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'remove'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['tariffs'],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'cut'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['imports'],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'allow'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'we',
#         'verb': 'want'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['problems'],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'defuse'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"We must quickly open our markets, remove trade barriers '
#                     'and\n'
#                     '  cut import tariffs to allow imports of U.S. Products, '
#                     'if we\n'
#                     '  want to defuse problems from possible U.S. '
#                     'Retaliation," said\n'
#                     '  Paul Sheen, chairman of textile exporters &lt;Taiwan '
#                     'Safe Group>.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'Sheen',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "A senior official of South Korea's trade promotion\n"
#                     '  association said the trade dispute between the U.S. And '
#                     'Japan\n'
#                     '  might also lead to pressure on South Korea, whose chief '
#                     'exports\n'
#                     '  are similar to those of Japan.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'official',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "A senior official of South Korea's trade promotion\n"
#                     '  association said the trade dispute between the U.S. And '
#                     'Japan\n'
#                     '  might also lead to pressure on South Korea, whose chief '
#                     'exports\n'
#                     '  are similar to those of Japan.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'dispute',
#         'verb': 'lead'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['surplus'],
#         'sentence': 'Last year South Korea had a trade surplus of 7.1 billion\n'
#                     '  dlrs with the U.S., Up from 4.9 billion dlrs in 1985.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'Korea',
#         'verb': 'have'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'In Malaysia, trade officers and businessmen said tough\n'
#                     '  curbs against Japan might allow hard-hit producers of\n'
#                     '  semiconductors in third countries to expand their sales '
#                     'to the\n'
#                     '  U.S.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'officers',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'In Malaysia, trade officers and businessmen said tough\n'
#                     '  curbs against Japan might allow hard-hit producers of\n'
#                     '  semiconductors in third countries to expand their sales '
#                     'to the\n'
#                     '  U.S.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'curbs',
#         'verb': 'allow'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'In Malaysia, trade officers and businessmen said tough\n'
#                     '  curbs against Japan might allow hard-hit producers of\n'
#                     '  semiconductors in third countries to expand their sales '
#                     'to the\n'
#                     '  U.S.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': '',
#         'verb': 'hit'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['sales'],
#         'sentence': 'In Malaysia, trade officers and businessmen said tough\n'
#                     '  curbs against Japan might allow hard-hit producers of\n'
#                     '  semiconductors in third countries to expand their sales '
#                     'to the\n'
#                     '  U.S.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'producers',
#         'verb': 'expand'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'In Hong Kong, where newspapers have alleged Japan has '
#                     'been\n'
#                     '  selling below-cost semiconductors, some electronics\n'
#                     '  manufacturers share that view.',
#         'sentiment': 'negative',
#         'subject': 'newspapers',
#         'verb': 'allege'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['semiconductors'],
#         'sentence': 'In Hong Kong, where newspapers have alleged Japan has '
#                     'been\n'
#                     '  selling below-cost semiconductors, some electronics\n'
#                     '  manufacturers share that view.',
#         'sentiment': 'negative',
#         'subject': 'Japan',
#         'verb': 'sell'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['view'],
#         'sentence': 'In Hong Kong, where newspapers have alleged Japan has '
#                     'been\n'
#                     '  selling below-cost semiconductors, some electronics\n'
#                     '  manufacturers share that view.',
#         'sentiment': 'negative',
#         'subject': 'manufacturers',
#         'verb': 'share'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'But other businessmen said such\n'
#                     '  a short-term commercial advantage would be outweighed '
#                     'by\n'
#                     '  further U.S. Pressure to block imports.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'businessmen',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'But other businessmen said such\n'
#                     '  a short-term commercial advantage would be outweighed '
#                     'by\n'
#                     '  further U.S. Pressure to block imports.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'advantage',
#         'verb': 'outweigh'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['imports'],
#         'sentence': 'But other businessmen said such\n'
#                     '  a short-term commercial advantage would be outweighed '
#                     'by\n'
#                     '  further U.S. Pressure to block imports.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': '',
#         'verb': 'block'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"That is a very short-term view," said Lawrence Mills,\n'
#                     '  director-general of the Federation of Hong Kong '
#                     'Industry.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'Mills',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['imports'],
#         'sentence': '"If the whole purpose is to prevent imports, one day it '
#                     'will\n'
#                     '  be extended to other sources.',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'prevent'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"If the whole purpose is to prevent imports, one day it '
#                     'will\n'
#                     '  be extended to other sources.',
#         'sentiment': 'positive',
#         'subject': 'it',
#         'verb': 'extend'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['trade'],
#         'sentence': 'Much more serious for Hong Kong\n'
#                     '  is the disadvantage of action restraining trade," he '
#                     'said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'restrain'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'Much more serious for Hong Kong\n'
#                     '  is the disadvantage of action restraining trade," he '
#                     'said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'he',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "Last year was Hong Kong's biggest export market,\n"
#                     '  accounting for over 30 pct of domestically produced '
#                     'exports.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': '',
#         'verb': 'account'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "Last year was Hong Kong's biggest export market,\n"
#                     '  accounting for over 30 pct of domestically produced '
#                     'exports.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': '',
#         'verb': 'produce'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['outcome'],
#         'sentence': 'The Australian government is awaiting the outcome of '
#                     'trade\n'
#                     '  talks between the U.S. And Japan with interest and '
#                     'concern,\n'
#                     '  Industry Minister John Button said in Canberra last '
#                     'Friday.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'government',
#         'verb': 'await'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The Australian government is awaiting the outcome of '
#                     'trade\n'
#                     '  talks between the U.S. And Japan with interest and '
#                     'concern,\n'
#                     '  Industry Minister John Button said in Canberra last '
#                     'Friday.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'Button',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': '"This kind of deterioration in trade relations between '
#                     'two\n'
#                     '  countries which are major trading partners of ours is a '
#                     'very\n'
#                     '  serious matter," Button said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'Button',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['concerns'],
#         'sentence': "He said Australia's concerns centred on coal and beef,\n"
#                     "  Australia's two largest exports to Japan and also "
#                     'significant\n'
#                     '  U.S. Exports to that country.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'He',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "He said Australia's concerns centred on coal and beef,\n"
#                     "  Australia's two largest exports to Japan and also "
#                     'significant\n'
#                     '  U.S. Exports to that country.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'centre'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['off'],
#         'sentence': 'Meanwhile U.S.-Japanese diplomatic manoeuvres to solve '
#                     'the\n'
#                     '  trade stand-off continue.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': '',
#         'verb': 'solve'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': "Japan's ruling Liberal Democratic Party yesterday "
#                     'outlined\n'
#                     '  a package of economic measures to boost the Japanese '
#                     'economy.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'rule'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['package'],
#         'sentence': "Japan's ruling Liberal Democratic Party yesterday "
#                     'outlined\n'
#                     '  a package of economic measures to boost the Japanese '
#                     'economy.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'Party',
#         'verb': 'outline'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['economy'],
#         'sentence': "Japan's ruling Liberal Democratic Party yesterday "
#                     'outlined\n'
#                     '  a package of economic measures to boost the Japanese '
#                     'economy.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'boost'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The measures proposed include a large supplementary '
#                     'budget\n'
#                     '  and record public works spending in the first half of '
#                     'the\n'
#                     '  financial year.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'propose'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['budget'],
#         'sentence': 'The measures proposed include a large supplementary '
#                     'budget\n'
#                     '  and record public works spending in the first half of '
#                     'the\n'
#                     '  financial year.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'measures',
#         'verb': 'include'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'The measures proposed include a large supplementary '
#                     'budget\n'
#                     '  and record public works spending in the first half of '
#                     'the\n'
#                     '  financial year.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'record'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'They also call for stepped-up spending as an emergency\n'
#                     '  measure to stimulate the economy despite Prime '
#                     'Minister\n'
#                     "  Yasuhiro Nakasone's avowed fiscal reform program.\n"
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'They',
#         'verb': 'call'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'They also call for stepped-up spending as an emergency\n'
#                     '  measure to stimulate the economy despite Prime '
#                     'Minister\n'
#                     "  Yasuhiro Nakasone's avowed fiscal reform program.\n"
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': '',
#         'verb': 'step'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['economy'],
#         'sentence': 'They also call for stepped-up spending as an emergency\n'
#                     '  measure to stimulate the economy despite Prime '
#                     'Minister\n'
#                     "  Yasuhiro Nakasone's avowed fiscal reform program.\n"
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': '',
#         'verb': 'stimulate'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'They also call for stepped-up spending as an emergency\n'
#                     '  measure to stimulate the economy despite Prime '
#                     'Minister\n'
#                     "  Yasuhiro Nakasone's avowed fiscal reform program.\n"
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': '',
#         'verb': 'avow'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'Deputy U.S. Trade Representative Michael Smith and '
#                     'Makoto\n'
#                     "  Kuroda, Japan's deputy minister of International Trade "
#                     'and\n'
#                     '  Industry (MITI), are due to meet in Washington this '
#                     'week in an\n'
#                     '  effort to end the dispute.\n'
#                     '  \n'
#                     '\n',
#         'sentiment': 'negative',
#         'subject': '',
#         'verb': 'meet'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['dispute'],
#         'sentence': 'Deputy U.S. Trade Representative Michael Smith and '
#                     'Makoto\n'
#                     "  Kuroda, Japan's deputy minister of International Trade "
#                     'and\n'
#                     '  Industry (MITI), are due to meet in Washington this '
#                     'week in an\n'
#                     '  effort to end the dispute.\n'
#                     '  \n'
#                     '\n',
#         'sentiment': 'negative',
#         'subject': '',
#         'verb': 'end'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['EAT'],
#         'sentence': 'CHINA DAILY SAYS VERMIN EAT 7-12 PCT GRAIN STOCKS\n'
#                     '  A survey of 19 provinces and seven cities\n'
#                     '  showed vermin consume between seven and 12 pct of '
#                     "China's grain\n"
#                     '  stocks, the China Daily said.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'DAILY',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['consume'],
#         'sentence': 'CHINA DAILY SAYS VERMIN EAT 7-12 PCT GRAIN STOCKS\n'
#                     '  A survey of 19 provinces and seven cities\n'
#                     '  showed vermin consume between seven and 12 pct of '
#                     "China's grain\n"
#                     '  stocks, the China Daily said.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'survey',
#         'verb': 'show'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'CHINA DAILY SAYS VERMIN EAT 7-12 PCT GRAIN STOCKS\n'
#                     '  A survey of 19 provinces and seven cities\n'
#                     '  showed vermin consume between seven and 12 pct of '
#                     "China's grain\n"
#                     '  stocks, the China Daily said.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'Daily',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'It also said that each year 1.575 mln tonnes, or 25 pct, '
#                     'of\n'
#                     "  China's fruit output are left to rot, and 2.1 mln "
#                     'tonnes, or up\n'
#                     '  to 30 pct, of its vegetables.',
#         'sentiment': 'neutral',
#         'subject': 'It',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'It also said that each year 1.575 mln tonnes, or 25 pct, '
#                     'of\n'
#                     "  China's fruit output are left to rot, and 2.1 mln "
#                     'tonnes, or up\n'
#                     '  to 30 pct, of its vegetables.',
#         'sentiment': 'neutral',
#         'subject': 'tonnes',
#         'verb': 'leave'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'It also said that each year 1.575 mln tonnes, or 25 pct, '
#                     'of\n'
#                     "  China's fruit output are left to rot, and 2.1 mln "
#                     'tonnes, or up\n'
#                     '  to 30 pct, of its vegetables.',
#         'sentiment': 'neutral',
#         'subject': '',
#         'verb': 'rot'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['waste'],
#         'sentence': 'The paper blamed the waste on\n'
#                     '  inadequate storage and bad preservation methods.\n'
#                     '      ',
#         'sentiment': 'negative',
#         'subject': 'paper',
#         'verb': 'blame'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'It said the government had launched a national programme '
#                     'to\n'
#                     '  reduce waste, calling for improved technology in '
#                     'storage and\n'
#                     '  preservation, and greater production of additives.',
#         'sentiment': 'positive',
#         'subject': 'It',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['programme'],
#         'sentence': 'It said the government had launched a national programme '
#                     'to\n'
#                     '  reduce waste, calling for improved technology in '
#                     'storage and\n'
#                     '  preservation, and greater production of additives.',
#         'sentiment': 'positive',
#         'subject': 'government',
#         'verb': 'launch'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['waste'],
#         'sentence': 'It said the government had launched a national programme '
#                     'to\n'
#                     '  reduce waste, calling for improved technology in '
#                     'storage and\n'
#                     '  preservation, and greater production of additives.',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'reduce'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'It said the government had launched a national programme '
#                     'to\n'
#                     '  reduce waste, calling for improved technology in '
#                     'storage and\n'
#                     '  preservation, and greater production of additives.',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'call'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['details'],
#         'sentence': 'The paper\n  gave no further details.\n  \n\n',
#         'sentiment': 'neutral',
#         'subject': 'paper',
#         'verb': 'give'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'JAPAN TO REVISE LONG-TERM ENERGY DEMAND DOWNWARDS\n'
#                     '  The Ministry of International Trade and\n'
#                     '  Industry (MITI) will revise its long-term energy '
#                     'supply/demand\n'
#                     '  outlook by August to meet a forecast downtrend in '
#                     'Japanese\n'
#                     '  energy demand, ministry officials said.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'JAPAN',
#         'verb': 'revise'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['outlook'],
#         'sentence': 'JAPAN TO REVISE LONG-TERM ENERGY DEMAND DOWNWARDS\n'
#                     '  The Ministry of International Trade and\n'
#                     '  Industry (MITI) will revise its long-term energy '
#                     'supply/demand\n'
#                     '  outlook by August to meet a forecast downtrend in '
#                     'Japanese\n'
#                     '  energy demand, ministry officials said.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'REVISE',
#         'verb': 'revise'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['downtrend'],
#         'sentence': 'JAPAN TO REVISE LONG-TERM ENERGY DEMAND DOWNWARDS\n'
#                     '  The Ministry of International Trade and\n'
#                     '  Industry (MITI) will revise its long-term energy '
#                     'supply/demand\n'
#                     '  outlook by August to meet a forecast downtrend in '
#                     'Japanese\n'
#                     '  energy demand, ministry officials said.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': '',
#         'verb': 'meet'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'JAPAN TO REVISE LONG-TERM ENERGY DEMAND DOWNWARDS\n'
#                     '  The Ministry of International Trade and\n'
#                     '  Industry (MITI) will revise its long-term energy '
#                     'supply/demand\n'
#                     '  outlook by August to meet a forecast downtrend in '
#                     'Japanese\n'
#                     '  energy demand, ministry officials said.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'officials',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'MITI is expected to lower the projection for primary '
#                     'energy\n'
#                     '  supplies in the year 2000 to 550 mln kilolitres (kl) '
#                     'from 600\n'
#                     '  mln, they said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'MITI',
#         'verb': 'expect'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['projection'],
#         'sentence': 'MITI is expected to lower the projection for primary '
#                     'energy\n'
#                     '  supplies in the year 2000 to 550 mln kilolitres (kl) '
#                     'from 600\n'
#                     '  mln, they said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': '',
#         'verb': 'lower'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': [],
#         'sentence': 'MITI is expected to lower the projection for primary '
#                     'energy\n'
#                     '  supplies in the year 2000 to 550 mln kilolitres (kl) '
#                     'from 600\n'
#                     '  mln, they said.\n'
#                     '      ',
#         'sentiment': 'positive',
#         'subject': 'they',
#         'verb': 'say'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['emergence'],
#         'sentence': 'The decision follows the emergence of structural changes '
#                     'in\n'
#                     '  Japanese industry following the rise in the value of '
#                     'the yen\n'
#                     '  and a decline in domestic electric power demand.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': 'decision',
#         'verb': 'follow'},
#     {   'date': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999),
#         'objects': ['rise'],
#         'sentence': 'The decision follows the emergence of structural changes '
#                     'in\n'
#                     '  Japanese industry following the rise in the value of '
#                     'the yen\n'
#                     '  and a decline in domestic electric power demand.\n'
#                     '      ',
#         'sentiment': 'neutral',
#         'subject': '',
#         'verb': 'follow'}]
